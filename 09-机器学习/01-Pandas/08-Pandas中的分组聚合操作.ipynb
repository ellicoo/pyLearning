# %%
import pandas as pd

# %%
df = pd.read_csv('./uniqlo.csv')
df
# Out:
#        store_id city channel gender_group age_group  wkd_ind product  \
# 0           658   深圳      线下       Female     25-29  Weekday    当季新品
# 1           146   杭州      线下       Female     25-29  Weekday      运动
# 2            70   深圳      线下         Male      >=60  Weekday      T恤
# 3           658   深圳      线下       Female     25-29  Weekday      T恤
# 4           229   深圳      线下         Male     20-24  Weekend      袜子
# ...         ...  ...     ...          ...       ...      ...     ...
# 22288       146   杭州      线下       Female     30-34  Weekday      短裤
# 22289       430   成都      线下       Female     25-29  Weekend      T恤
# 22290       449   武汉      线下       Female     35-39  Weekday      T恤
# 22291       758   杭州      线下       Female     20-24  Weekday      袜子
# 22292       616   成都      线下         Male     30-34  Weekday    当季新品
#
#        customer  revenue  order  quant  unit_cost
# 0             4    796.0      4      4         59
# ...

# %%
# 1. 分组操作实现

# %%
df.groupby(['city'])

# %%
df.groupby(['city', 'channel'])

# %%
gs2 = df.groupby(['city'])

# %%
gs2.first()
# Out:
#       store_id channel gender_group age_group  wkd_ind product  customer  \
# city
# 上海         135      线下       Female     30-34  Weekend    当季新品         1
# 北京          21      线下       Female     45-49  Weekend      毛衣         1
# 南京          19      线下       Female     35-39  Weekend      T恤         4
# 广州         420      线上         Male      >=60  Weekday      T恤         1
# 成都         430      线下         Male     35-39  Weekend      裙子         1
# 杭州         146      线下       Female     25-29  Weekday      运动         1
# 武汉          28      线上       Female     35-39  Weekend      T恤         1
# 深圳         658      线下       Female     25-29  Weekday    当季新品         4
# 西安         648      线下         Male     20-24  Weekend      T恤         1
# 重庆         208      线下         Male     20-24  Weekend      配件         1
#
#       revenue  order  quant  unit_cost
# city
# 上海       49.0      1      1         59
# 北京      199.0      1      1         99
# ...

# %%
gs2.last()
# Out:
#       store_id channel gender_group age_group  wkd_ind product  customer  \
# city
# 上海         335      线下       Female     35-39  Weekend      运动         3
# 北京          21      线下       Female     35-39  Weekend      T恤         1
# 南京          19      线下       Female     45-49  Weekend      短裤         1
# 广州         182      线上       Female     25-29  Weekday    当季新品         3
# 成都         616      线下         Male     30-34  Weekday    当季新品         1
# 杭州         758      线下       Female     20-24  Weekday      袜子         1
# 武汉         449      线下       Female     35-39  Weekday      T恤         1
# 深圳         738      线下       Female     45-49  Weekday      配件         1
# 西安         429      线下         Male     25-29  Weekday      T恤         1
# 重庆         208      线下       Female     45-49  Weekend      T恤         1
#
#       revenue  order  quant  unit_cost
# city
# 上海      447.0      3      3         49
# 北京       59.0      1      1         49
# ...

# %%
gs2.get_group(('深圳'))
# Out:
#        store_id channel gender_group age_group  wkd_ind product  customer  \
# 0           658      线下       Female     25-29  Weekday    当季新品         4
# 2            70      线下         Male      >=60  Weekday      T恤         2
# 3           658      线下       Female     25-29  Weekday      T恤         1
# 4           229      线下         Male     20-24  Weekend      袜子         2
# 13          611      线下         Male     30-34  Weekend      T恤         1
# ...         ...     ...          ...       ...      ...     ...       ...
# 22272       738      线下         Male     35-39  Weekend      T恤         1
# 22277       611      线下         Male     20-24  Weekday      T恤         1
# 22278        70      线下         Male      >=60  Weekend      短裤         1
# 22281       280      线下       Female     30-34  Weekend      短裤         1
# 22283       738      线下       Female     45-49  Weekday      配件         1
#
#        revenue  order  quant  unit_cost
# ...

# %%
df.groupby(['city', 'channel']).agg({
    'revenue':'mean',
    'unit_cost':'sum'
})
# Out:
#                  revenue  unit_cost
# city channel
# 上海   线上       187.603426      27980
#      线下       154.623043      82359
# 北京   线下       226.098128      26163
# 南京   线下       246.301860      23140
# 广州   线上       153.470817      59631
#      线下       133.368817      41091
# 成都   线下       136.160798      72041
# 杭州   线下       155.751252     173445
# 武汉   线上       180.977961      69225
#      线下       153.258971      93858
# 深圳   线下       167.993511     201526
# 西安   线上       128.581239      10246
#      线下       131.791838      64469
# 重庆   线上       144.672253       8028
#      线下       147.764673      75055

# %%
df.groupby(['city']).filter(lambda s:s['revenue'].mean() > 200).city.unique()
# Out:
# array(['北京', '南京'], dtype=object)

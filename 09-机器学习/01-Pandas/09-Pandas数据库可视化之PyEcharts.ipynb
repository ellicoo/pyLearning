# %%
from pyecharts.charts import Line

# %%
line = Line()
line.add_xaxis(['2023-01-01', '2023-01-02', '2023-01-03'])
line.add_yaxis('销售额', [100, 150, 300])

# %%
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="34c1877ecc7b4c36af588ec28fbdc550" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_34c1877ecc7b4c36af588ec28fbdc550 = echarts.init(
#                     document.getElementById('34c1877ecc7b4c36af588ec28fbdc550'), 'white', {renderer: 'canvas'});
#                 var option_34c1877ecc7b4c36af588ec28fbdc550 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker

c = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5ff4919e194d4842b479fb74a4fa727a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5ff4919e194d4842b479fb74a4fa727a = echarts.init(
#                     document.getElementById('5ff4919e194d4842b479fb74a4fa727a'), 'white', {renderer: 'canvas'});
#                 var option_5ff4919e194d4842b479fb74a4fa727a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 扩展Faker类的使用 => 模拟数据类/随机数据类

# %%
from pyecharts.faker import Faker

# %%
Faker.choose()
# Out:
# ['河马', '蟒蛇', '老虎', '大象', '兔子', '熊猫', '狮子']

# %%
Faker.values()
# Out:
# [101, 118, 50, 128, 99, 66, 135]

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

# %%
c = Bar()
c.add_xaxis(['小明', '小美', '小兰'])
c.add_yaxis("本月销售额汇总", [58964, 60000, 49527])
c.set_global_opts(
    title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="和涛哥学习pyecharts"),
    toolbox_opts=opts.ToolboxOpts(is_show=True)
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3c9d033bc4c249aa87b85ef55da49032" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3c9d033bc4c249aa87b85ef55da49032 = echarts.init(
#                     document.getElementById('3c9d033bc4c249aa87b85ef55da49032'), 'white', {renderer: 'canvas'});
#                 var option_3c9d033bc4c249aa87b85ef55da49032 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 饼状图实现

# %%
# 前置知识点

# %%
a = [1, 2, 3]
b = [11, 22, 33]
c = [111, 222, 333]

# %%
newlist1 = zip(a)
list(newlist1)
# Out:
# [(1,), (2,), (3,)]

# %%
newlist2 = zip(a, b)
list(newlist2)
# Out:
# [(1, 11), (2, 22), (3, 33)]

# %%
newlist3 = zip(a, b, c)
list(newlist3)
# Out:
# [(1, 11, 111), (2, 22, 222), (3, 33, 333)]

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = Pie()
c.add("", [list(z) for z in zip(['可乐', '面包', '奥利奥'], [10, 20, 30])])  # for z in [('可乐', 10), ('面包', 20), ('奥利奥', 30)]
c.set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
c.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="276b0afc003a49bebd258f6c3e07e2db" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_276b0afc003a49bebd258f6c3e07e2db = echarts.init(
#                     document.getElementById('276b0afc003a49bebd258f6c3e07e2db'), 'white', {renderer: 'canvas'});
#                 var option_276b0afc003a49bebd258f6c3e07e2db = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
